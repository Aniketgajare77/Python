# %%
print('     WELCOME     ')
print('*******************************')

while True:
    print('-------------------------------------------------------') 
    print('select your choice')

    print("MENU")
    print("-------------------")
    print("1.List\n2.Tuple\n3.set\n4.dictionary\n5.exit")
    print('--------------------------------------')
    ch=int(input("select option from above"))
    l=[1,2,3,4,5]
    tup=(1,2,3,4,5,6)
    se={1,2,3,4,5,6,7}
    dic={1:2,3:4,5:6,7:8}

    if ch==1:
        while True:
            print('YOU SELECT LIST OPERATION')
            print('-------------------------------------')
            print("List Operations")
            print("--------------------------------------")
            print("1.Def\n2.add elements into the list\n3.Deletion\n4.Exit")

            l1= int(input("select option from list"))


            if l1==1:
                print('YOU SELECT DEFINITION OF LIST')
                print('-------------------')

                print('-------------------')
                print("Lists are used to store multiple items in a single variable.\nLists are created using square brackets\nList items are ordered, changeable, and allow duplicate values.")
                continue
            elif l1==2:
                 while True:
                    print('YOU SELECT ADDITION OF LIST')    
                    print('************************************')
                    print("Addition Method")
                    print("*****************************")
                    print("1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Do you want to add element at Specific index position\n4.Exit")


                    la=int(input('select option for addititon'))
                    if la==1:
                        print('YOU SELECT ADD A SINGLE ELEMENT')
                        print('***********************************')
                        print(l)
                        l.append(int(input('Enter a number u want to add: ')))
                        print('output=',l)
                        continue
                    elif la==2:
                        print('YOU SELECT ADD A MULTIPLE ELEMENT')
                        print('*******************************************')
                        new_list=[]
                        n=int(input("Enter numbers of ele you want to add: "))
                        for i in range(0, n):
                            ele = input()
                            new_list.append(ele)
                        l.extend(new_list)
                        print('output=',l)
                        continue

                    elif la==3:
                        i= int(input('Enter index number: '))
                        n= int(input('enter a number: '))
                        l.insert(i,n)
                        print('output=',l)
                        continue
                    elif la==4:
                        break
                    else:
                        print("wrong Choice")
                        continue
            elif l1==3:
                while(True):

                    print('YOU SELECT DELETION METHOD')
                    print('********************************')
                    print('deletion method')
                    print('--------------------------------')
                    print('1.Do you want to Delete element of the end\n2.Do you want to delete specific value from the list\n3.Do you want to delete element at specfic index position\n4:Exit')
                    print('****************************************************************************************************************************************************************************')
                    ld=int(input('select option for deletion '))
                    if ld==1:

                        print('YOU SELECT POP METHOD')
                        print('***************************')
                        print(l)
                        l.pop()
                        print('output=',l)
                        continue
                    elif ld==2:
                        print('YOU SELECT REMOVE METHOD')
                        print('************************************')
                        print(l)
                        n=int(input('enter a value which you want to delete'))
                        if n in l:
                                l.remove(n)
                                print('output=',l)
                        else:
                                print('enter correct value')
                        continue
                    elif ld==3:
                        print('YOU SELECT INDEX METHOD')
                        print('******************************')
                        print(l)
                        i=int(input('Enter index position of deletion element'))
                        del l[i]
                        print('output=',l)
                        continue
                    elif ld==4:
                        print('YOU SELECT EXIT BUTTON')
                        print('****************************************')
                        break
                    else:
                        print('Wrong choice')
                        print('******************************')
            elif l1==4:
                print('YOU SELECT EXIT BUTTON')
                break
            else:
                print('Wrong Choice')
                continue
    elif ch==2:
        while(True):
            
            print('****************************************************************')
            print('YOU SELECT TUPLE OPERATION')
            print('-----------------------------------------------------------------')
            print('tuple operation')
            print('1.Def\n2.add elements into tuple\n3.Deletion\n4.Exit')
            t1=int(input('select options for tuple'))
            
            if t1==1:
                print('YOU SELECT DEFINITION')
                print('***********************************')
                print('defintion of tuple is ')
                print('Tuple are use to store multiple value at single variable.tuple is ordered and unchangeble')
                continue
            elif t1==2:
                while(True):
                    
                    print('YOU SELECT ADDITTION OF TUPLE')
                    print('*************************************************')
                    print('addititon method')
                    print('---------------------------------')
                    print('1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Do you want to add element at Specific index position\n4.Exit')
                    print('------------------------------------------------------------------')
                    ta=int(input('select option for addition tuple'))
                    if ta==1:
                        print('YOU SELECT SINGLE ELEMENET')
                        print('***********************************')
                        print('tuple before adding',tup)
                        tup=list(tup)
                        tup.append(int(input('enter a element you want to add')))
                        tup=tuple(tup)
                        print('output=',tup)
                        continue
                    elif ta==2:
                        print('YOU SELECT MULTIPLE ELEMENT ADD')
                        print('***************************************')
                        print('tuple before adding',tup)
                        tup=list(tup)
                        lst=[]
                        n=int(input('enter number you want to add'))
                        for i in range(0,n):
                            ele=input()
                            lst.append(ele)
                        tup.extend(lst)
                        tup=tuple(tup)
                        print('output=',tup)
                        print('--------------------------------------')
                        continue
                    elif ta==3:
                        print('YOU SELECT ADD AT SPECIFIC ELEMENT')
                        print('*****************************************')
                        print('tuple before adding',tup)
                        tup=list(tup)
                        i=int(input('enetr a index number you want to add'))
                        n=int(input('enter a number you want aadd'))
                        tup.insert(i,n)
                        tup=tuple(tup)
                        print('output=',tup)
                        continue
                    elif ta==4:
                        print('YOU SELECT EXIT BUTTON')
                        print('***********************************')
                        break
                    else:
                        print('*******Wrong choice*****************')
                        continue
            elif t1==3:
                while(True):
                    print('YOU SELECT DELETION METHOD OF TUPLE')
                    print('*******************************************')
                    print('deletion method')
                    print('-------------------------------------------')
                    print('1.Do you want to Delete element of the end\n2.Do you want to delete specific value from the list\n3.Do you want to delete element at specific index position\n4.Exit')
                    print('*********************************************')
                    td=int(input('enter option for deletion tuple'))
                    if td==1:
                        print('YOU SELECT DELETE AT END')
                        print('*******************************************')
                        print('we use pop')
                        print('--------------------------')
                        print('before deletion',tup)
                        tup=list(tup)
                        tup.pop()
                        tup=tuple(tup)
                        print('output=',tup)
                        continue
                    elif td==2:
                        print('YOU SELECT DELETE AT SPECIFIC')
                        print('******************************************************')
                        print('we use remove')
                        print('----------------------------------')
                        print('before deletion',tup)
                        tup=list(tup)
                        n=int(input('enter a element you want to delete'))
                        if n in tup:
                            tup.remove(n)
                            tup=tuple(tup)
                            print('output=',tup)
                        else:
                            print('enter a encorrect value')
                            continue
                    elif td==3:
                        print('YOU SELECT DELETE AT SPECIFIC INDEX')
                        print('****************************************')
                        print('we use del')
                        print('---------------------------------------')
                        print('before deletion',tup)
                        tup=list(tup)
                        n=int(input('enter index number'))
                        del tup[n]
                        tup=tuple(tup)
                        print('output=',tup)
                        continue
                    elif td==4:
                        print('YOU SELECT EXIT BUTTON')
                        print('***************************')
                        break
                    else:
                        print('***********wrong choice**********')
                        print('----------------------------------')
                        continue
            elif t1==4:
                print('YOU SELECT EXIT BUTTON')
                print('******************************')
                break
            else:
                print('*******Wrong choice************')
    elif ch==3:
        while(True):
            print('YOU SELECT SET OPERATION')
            print('******************************************')
            print('set operation')
            print('-----------------------------------------')
            print('1.Def\n2.add elements into set\n3.Deletion\n4.Exit')
            s1=int(input('enter option for set'))
            print('--------------------------------')
            
            if s1==1:
                print('YOU SELECT DEFINITON OF SET ')
                print('**********************************')
                print('defintion of set is:-')
                print('set is unordered collection of data which is mutable,iterable,and no duplicate element and set is defined by {} bracket')
                print('-------------------------------------------------------')
                continue
            
            elif s1==2:
                while(True):
                    print('YOU SELECT ADDITITON OF SET')
                    print('**************************************************************')
                    print('addititon method')
                    print('-----------------------------------')
                    print('1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Exit')
                    sa=int(input('enter option for addition'))
                    print('-----------------------------')
                    if sa==1:
                        print('YOU SELECCT ADD SINGLE ELEMENT')
                        print('--------------------------------------')
                        print('we use add method')
                        print('**************************************')
                        print(se)
                        n=int(input('enter element you want to add'))
                        se.add(n)
                        print('output=',se)
                        continue
                    
                    elif sa==2:
                        print('YOU SELECT ADD MULTIPLE ELEMENT')
                        print('************************************************')
                        print('we use update method')
                        print('-------------------------------------')
                        new_set=[]
                        n=int(input('enter number of element you want add'))
                        for i in range(0,n):
                            ele=input()
                            new_set.append(ele)
                        se.update(new_set)
                        print('output=',se)
                        continue
                    elif sa==3:
                        print('YOU CHOSE EXIT BUTTON')
                        print('******************************')
                        break
                    else:
                        print('******Wrong choice***********')
                        continue
                   
            elif s1==3:
                while(True):
                    
                    print('YOU SELECT DELETION OF SET')
                    print('*********************************')
                    print('deletion method')
                    print('---------------------------')
                    print('1.Do you want to delete specific value from the set\n2.Do you want to delete all the elements from the set\n3.Exit')
                    print('-------------------------------------------------')
                    sd=int(input('enter option from deletion'))
                    print('-------------------------------------------')
                    if sd==1:
                        print('YOU SELECT DELETE AT SPECIFIC VALUE')
                        print('************************************')
                        print('we use remove')
                        print('----------------------------')
                        print(se)
                        n=int(input('enter a element you want to delete'))
                        se.remove(n)
                        print('output=',se)
                        continue
                    elif sd==2:
                        print('YOU SELECT DELETE ALL ELEMENT')
                        print('****************************************')
                        print('we use clear method')
                        print('------------------------------------------')
                        print(se)
                        se.clear()
                        print('output=',se)
                        continue
                    elif sd==3:
                        print('YOU SELECT EXIT BUTTON')
                        print('************************************')
                        break
                    else:
                        print('***********wrong choice*******************')
                        print('--------------------------------------------------')
                        continue
            elif s1==4:
                print('YOU SELECT EXIT BUTTON')
                print('************************************')
                break
            else:
                print('******Wrong choice***********')
                print('--------------------------------------')
    elif ch==4:
        while(True):
            print('YOU SELECT DICTIONARY OPERATION ')
            print('******************************************')
            print('dictionary operation')
            print('---------------------------------------------')
            print('1.Defination\n2.Add elemnts into Dictionary\n3.Deletion of elements from Dictionary\n4.Exit')
            print('----------------------------------------------')
            d1=int(input('enter option from dictionary'))
            
            if d1==1:
                print('YOU SELECT DEFINTION OF DICTIONARY')
                print('*****************************************')
                print('defintion of dictionary is:-')
                print('Dictionaries are used to store data values in key:value pairs.A dictionary is a collection which is ordered*, changeable and do not allow duplicates.Dictionaries are written with curly brackets, and have keys and values')
                print('---------------------------------------------------')
                continue
            elif d1==2:
                while(True):
                    
                    print('YOU SELECT ADDITION OF DICTIONARY')
                    print('*******************************************')
                    print('addition method')
                    print('--------------------------')
                    print('1.Do you want update single element\n2.Do you want to add a new element with a key and value\n3.Do you want to add multiple new elements\n4.exit')
                    print('----------------------------------------------------')
                    da=int(input('enter a option from addition'))
                    if da==1:
                        print('YOU SELECT UPDATE SINGLE ELEMENT')
                        print('********************************************')
                        print('display dictionary before adding',dic)
                        key=int(input('enter key to add'))
                        value=int(input('enter a new value'))
                        if key in dic:
                            dic[key]=value
                            print('output=',dic)
                        else:
                            print('enter key does not exist in dictionary')
                        continue
                    elif da==2:
                        print('YOU SELECT ADD ELEMENT WITH KEY AND VALUE')
                        print('****************************************************')
                        print('display dictionary before adding',dic)
                        key=int(input('enter key to add'))
                        value=int(input('enter a new value'))
                        if key in dic:
                            print('key already exist in dictionary')
                        else:
                            dic[key]=value
                            print('output=',dic)
                        continue
                    elif da==3:
                        print('YOU SELECT ADD MULTIPLE ELEMENT')
                        print('******************************************')
                        print('display dictionary before adding',dic)
                        n=int(input('enter number of elements you want to add'))
                        for i in range(n):
                            key=int(input('enter key to add'))
                            value=int(input('enter a new value'))
                            if key in dic:
                                print('key is already exist in dictionary')
                            else:
                                dic[key]=value
                                print('output=',dic)
                            continue
                    elif da==4:
                        print('YOU SELECT EXIT BUTTON')
                        print('*********************************')
                        break
                    else:
                        print('*************Wrong choice****************')
                        print('------------------------------------------')
            elif d1==3:
                while(True):
                    print('YOU SELECT DELETION OF DICTIONARY')
                    print('***********************************************')
                    print('deletion method')
                    print('----------------------------------')
                    print('1.Deletion of element(s)\n2.Exit')
                    dd=int(input('enter option from deletion'))
                    if dd==1:
                        print('YOU SELECT DELETION OF ELEMENT')
                        print('****************************************')
                        print('display a dictionary before deletion',dic)
                        key=int(input('enter a key to delete'))
                        if key in dic:
                            del dic[key]
                            print('output=',dic)
                        else:
                            print('enter key doses not exist')
                        continue
                    elif dd==2:
                        print('YOU SELECT EXIT BUTTON')
                        print('**************************************')
                        break
            elif d1==4:
                     
                    print('YOU SELECT EXIT BUTTON')
                    print('*****************************')
                    break
    elif ch==5:
        print('YOU SELECT EXIT BUTTON')
        print('********************************')
        break
    else:
        print('******Wrong choice**************')
# Out:
#      WELCOME
# *******************************
# -------------------------------------------------------
# select your choice
# MENU
# -------------------
# 1.List
# 2.Tuple
# 3.set
# 4.dictionary
# 5.exit
# --------------------------------------
# select option from above1
# YOU SELECT LIST OPERATION
# -------------------------------------
# List Operations
# --------------------------------------
# 1.Def
# 2.add elements into the list
# 3.Deletion
# 4.Exit
# select option from list4
# YOU SELECT EXIT BUTTON
# -------------------------------------------------------
# select your choice
# MENU
# -------------------
# 1.List
# 2.Tuple
# 3.set
# 4.dictionary
# 5.exit
# --------------------------------------
# select option from above2
# ****************************************************************
# YOU SELECT TUPLE OPERATION
# -----------------------------------------------------------------
# tuple operation
# 1.Def
# 2.add elements into tuple
# 3.Deletion
# 4.Exit
# ...
