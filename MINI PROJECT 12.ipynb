# %%
print('******Welcome******')
print('-------------------------')
while(True):
    print("*****************************************************************************")
    print("\t                     Select the choice")
    print("1.    List\n2.    Tuple\n3.    Dictionary\n4.    SET\n5.    Quit")   
    print("*****************************************************************************")
    ch=int(input('select option from above'))
    l=[1,2,3,4,5,6]
    t=(1,2,3,4,5,6,7)
    s={1,2,3,4,5,6,7,8}
    if ch>5:
        print('you enter a wrong choice')
    elif ch==1:
        while(True):
            print('YOU SELECT LIST OPTION')
            print('------------------------------')
            print('1:Def\n2.Add elemnts into the list\n3.Deletion\n4.exit')
            print('**********************************')
            l1=int(input('select option for list'))
            if l1==1:
                print('YOU SELECT DEFINTION')
                print('----------------------------')
                print('list is collection of data which is ordered and have a heterogenous element which are mutuable and made by square bracket')
                print('*********************************')
            elif l1==2:
                while(True):
                    print('YOU SELECT ADDITITON METHOD')
                    print('**********************************')
                    
                    print('1:Do you want to add elements single element\n2:Do you want to add multiple elements\n3.Do you want to ad element at sprcific index position\n4:exit')
                    print('********************************************************************************************************************************************************')
                    la=('SELECT OPTIONS FOR ADDITION')
                    print('------------------------------')
                    if la==1:
                        print('YOU SELECT ADD A SINGLE ELEMENT')
                        print(l)
                        l.append(int(input('enter a number what  you want to add')))
                        print('output',l)
                    elif la==2:
                        print('Addition multiple Element')
                        new_list=[]
                        n=int(input("Enter numbers of ele you want to add: "))
                        for i in range(0, n):
                            ele = input()
                            new_list.append(ele)
                        l.extend(new_list)
                        print(l)
                        
                    elif la==3:
                        i=int(input('Enter a position at which you want to add element'))
                        n=int(input('enter a number you want to add'))
                        l.insert(i,n)
                        print('output',l)
                    elif la==4:
                        print('you chose Exit button')
                        print('*****************************')
                        print('----------------------------------')
                        break
                    else:
                        print('**Wrong choice**')
                        print('*******************************************************************')
# Out:
# ******Welcome******
# -------------------------
# *****************************************************************************
# 	                     Select the choice
# 1.    List
# 2.    Tuple
# 3.    Dictionary
# 4.    SET
# 5.    Quit
# *****************************************************************************
# select option from above1
# YOU SELECT LIST OPTION
# ------------------------------
# 1:Def
# 2.Add elemnts into the list
# 3.Deletion
# 4.exit
# **********************************
# select option for list1
# YOU SELECT DEFINTION
# ----------------------------
# list is collection of data which is ordered and have a heterogenous element which are mutuable and made by square bracket
# *********************************
# YOU SELECT LIST OPTION
# ------------------------------
# 1:Def
# 2.Add elemnts into the list
# 3.Deletion
# 4.exit
# **********************************
# select option for list2
# IOPub data rate exceeded.
# ...
